# %%
import pandas as pd
import pickle
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Tippu\Downloads\UCI_Credit_Card.csv\UCI_Credit_Card.csv")

# %%
data.info()
data.duplicated().sum() # no duplicates
data.isna().sum() # No missing values are present
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
# distributtion of credit amounts
#probability density 
fig=px.histogram(data,x='LIMIT_BAL')
fig.show()


# the distribution of credit limit balance shows the largest credit limit amount groups are 50k,20k,30k,80k,200k respectively.



#age distribution
fig=px.histogram(data,x='AGE')
fig.show()

#slightly right skewed
# Out:
# Unnamed: 0    0
# X1            0
# X2            0
# X3            0
# X4            0
# X5            0
# X6            0
# X7            0
# X8            0
# X9            0
# X10           0
# X11           0
# X12           0
# X13           0
# X14           0
# X15           0
# X16           0
# X17           0
# X18           0
# X19           0
# X20           0
# X21           0
# X22           0
# X23           0
# Y             0
# dtype: int64

# %%
m=data[data['SEX']==1]

fig=px.box(m['LIMIT_BAL'])
fig.show()


#################################################################################


females=data[data['SEX']==2]
males=data[data['SEX']==1]

fig,ax=plt.subplots()
ax.boxplot(males['LIMIT_BAL'],positions=[1],labels=['males'])
ax.boxplot(females['LIMIT_BAL'],positions=[2],labels=['Females'])

ax.set_xlabel('SEX')
ax.set_ylabel('LIMIT_BAL in millions')

# Show the plot
plt.show()

# %%
females=data[data['SEX']==2]
f1_a=females[females['MARRIAGE']==1] #married
f1_b=females[females['MARRIAGE']==2]  # single
f1_c=females[females['MARRIAGE']==3]  # others



males=data[data['SEX']==1]
m1_a=males[males['MARRIAGE']==1]
m1_b=males[males['MARRIAGE']==2]
m1_c=males[males['MARRIAGE']==3]



fig,ax=plt.subplots()
ax.boxplot(m1_a['AGE'],positions=[1],labels=['married_male'])
ax.boxplot(f1_a['AGE'],positions=[2],labels=['married_female'])

ax.boxplot(m1_b['AGE'],positions=[3],labels=['male_single'])
ax.boxplot(f1_b['AGE'],positions=[4],labels=['female_single'])

ax.boxplot(m1_c['AGE'],positions=[5],labels=['m_others'])
ax.boxplot(f1_c['AGE'],positions=[6],labels=['f_others'])




ax.set_xlabel('MARRIAGE')
ax.set_ylabel('AGE')

# Show the plot
plt.show()


#The dataset mostly contains couples in their mid-30s to mid-40s 
# and single people in their mid-20s to early-30s.

# %%
# replacing 0,6 in education to 5 

#EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown)
data['EDUCATION'].unique()
data['EDUCATION'].replace([0,6],5,inplace=True)
data['EDUCATION'].unique()



# replaced 0 with 3 in marriage column 
data['MARRIAGE'].value_counts()
data['MARRIAGE'].replace(0,3,inplace=True)
data['MARRIAGE'].unique()
# Out:
# array([2, 1, 3, 5, 4], dtype=int64)

# %%
# Out:
# array([1, 2, 3], dtype=int64)

# %%
# bar plot of default_payments 1/0
value_counts = data['default.payment.next.month'].value_counts()

# Bar Chart
plt.bar(value_counts.index, value_counts)

# Annotate each bar with its count value
for i, count in enumerate(value_counts):
    plt.text(i, count + 0.1, str(count), ha='center')
plt.xlabel('Values')
plt.ylabel('Count')
plt.title('Distribution of Binary Column')
# Set explicit x-axis ticks
plt.xticks([0, 1])
plt.show()


#  out of all about 22.12% of data shows defaulters

# %%
#grouping education & sex with defaut_payments

b=data.groupby(['SEX','EDUCATION'])['default.payment.next.month'].count()
b.plot(kind='bar')
for i, count in enumerate(b):
    plt.text(i, count + 0.1, str(count), ha='center')
plt.show()


#grouping sex with defaut_payments
a=data.groupby(['SEX'])['default.payment.next.month'].count()
a.plot(kind='bar')
for i, count in enumerate(a):
    plt.text(i, count + 0.1, str(count), ha='center')
    
plt.show()


#grouping education with defaut_payments
a=data.groupby(['EDUCATION'])['default.payment.next.month'].count()
a.plot(kind='bar')
for i, count in enumerate(a):
    plt.text(i, count + 0.1, str(count), ha='center')
plt.show()


#grouping education & marriage with defaut_payments
a=data.groupby(['EDUCATION','MARRIAGE'])['default.payment.next.month'].count()
a.plot(kind='bar')
for i, count in enumerate(a):
    plt.text(i, count + 0.1, str(count), ha='center')
plt.show()

# %%
#seperating input and output  data variables

X=data.drop(['default.payment.next.month'],axis=1)
y=data['default.payment.next.month']

# categorical input variable 
x_categ_data=X.loc[:,'SEX':'MARRIAGE']
x_categ_data
# Out:
#        SEX  EDUCATION  MARRIAGE
# 0        2          2         1
# 1        2          2         2
# 2        2          2         2
# 3        2          2         1
# 4        1          2         1
# ...    ...        ...       ...
# 29995    1          3         1
# 29996    1          3         2
# 29997    1          2         2
# 29998    1          3         1
# 29999    1          2         1
#
# [30000 rows x 3 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline


# initialise the instance
encoder=OneHotEncoder()

# Assuming encoder is your instance of the encoder you want to use
encode_pipeline = Pipeline(steps=[('encoder', encoder)])

# Assuming x_categ_data is a DataFrame with columns 'SEX' and 'MARRIAGE'
columns_to_encode = ['SEX', 'MARRIAGE']

encode_transform = ColumnTransformer(transformers=[('encoders', encode_pipeline, columns_to_encode)])
encode = encode_transform.fit(x_categ_data[columns_to_encode])

# Use transform on the specified columns and get_feature_names_out to name the columns
encoded_data = pd.DataFrame(encode.transform(x_categ_data[columns_to_encode]),
                            columns=encode.get_feature_names_out(columns_to_encode))



##encoded categorical data 
x_categ_Final=pd.concat([x_categ_data,encoded_data],axis=1)
x_categ_Final.drop(['SEX','MARRIAGE'],inplace=True,axis=1)
x_categ_Final
# Out:
#        EDUCATION  encoders__SEX_1  encoders__SEX_2  encoders__MARRIAGE_1  \
# 0              2              0.0              1.0                   1.0
# 1              2              0.0              1.0                   0.0
# 2              2              0.0              1.0                   0.0
# 3              2              0.0              1.0                   1.0
# 4              2              1.0              0.0                   1.0
# ...          ...              ...              ...                   ...
# 29995          3              1.0              0.0                   1.0
# 29996          3              1.0              0.0                   0.0
# 29997          2              1.0              0.0                   0.0
# 29998          3              1.0              0.0                   1.0
# 29999          2              1.0              0.0                   1.0
#
#        encoders__MARRIAGE_2  encoders__MARRIAGE_3
# ...

# %%
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64
